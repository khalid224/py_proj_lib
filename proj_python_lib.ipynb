# %%
import requests
import pandas as pd

url = "https://dummyjson.com/users?limit=100"

response = requests.get(url)
data = response.json()


df = pd.json_normalize(data["users"])

df.head()
# Out:
#    id firstName  lastName maidenName  age  gender  \
# 0   1     Emily   Johnson      Smith   29  female
# 1   2   Michael  Williams              36    male
# 2   3    Sophia     Brown              43  female
# 3   4     James     Davis              46    male
# 4   5      Emma    Miller    Johnson   31  female
#
#                               email             phone  username      password  \
# 0     emily.johnson@x.dummyjson.com  +81 965-431-3024    emilys    emilyspass
# 1  michael.williams@x.dummyjson.com  +49 258-627-6644  michaelw  michaelwpass
# 2      sophia.brown@x.dummyjson.com  +81 210-652-2785   sophiab   sophiabpass
# 3       james.davis@x.dummyjson.com  +49 614-958-9364    jamesd    jamesdpass
# 4       emma.miller@x.dummyjson.com  +91 759-776-1614     emmaj     emmajpass
#
#    ... company.address.city company.address.state company.address.stateCode  \
# 0  ...        San Francisco             Wisconsin                        WI
# 1  ...          Los Angeles         New Hampshire                        NH
# 2  ...               Dallas                Nevada                        NV
# 3  ...           Fort Worth          Pennsylvania                        PA
# 4  ...          San Antonio                 Idaho                        ID
#
#    company.address.postalCode  company.address.coordinates.lat  \
# 0                       37657                        71.814525
# 1                       73442                        79.098326
# 2                       88511                        20.086743
# 3                       27768                        54.911930
# 4                       21965                        44.346545
#
#   company.address.coordinates.lng company.address.country crypto.coin  \
# 0                     -161.150263           United States     Bitcoin
# 1                     -119.624845           United States     Bitcoin
# 2                      -34.577107           United States     Bitcoin
# 3                      -79.498328           United States     Bitcoin
# 4                      -26.944701           United States     Bitcoin
#
#                                 crypto.wallet    crypto.network
# 0  0xb9fc2fe63b2a6c003f1c324c3bfa53259162181a  Ethereum (ERC20)
# 1  0xb9fc2fe63b2a6c003f1c324c3bfa53259162181a  Ethereum (ERC20)
# 2  0xb9fc2fe63b2a6c003f1c324c3bfa53259162181a  Ethereum (ERC20)
# 3  0xb9fc2fe63b2a6c003f1c324c3bfa53259162181a  Ethereum (ERC20)
# 4  0xb9fc2fe63b2a6c003f1c324c3bfa53259162181a  Ethereum (ERC20)
#
# [5 rows x 52 columns]

# %%
df.shape
# Out:
# (100, 52)

# %%
df.columns.tolist()
# Out:
# ['id',
#  'firstName',
#  'lastName',
#  'maidenName',
#  'age',
#  'gender',
#  'email',
#  'phone',
#  'username',
#  'password',
#  'birthDate',
#  'image',
#  'bloodGroup',
#  'height',
#  'weight',
#  'eyeColor',
#  'ip',
#  'macAddress',
#  'university',
#  'ein',
#  'ssn',
#  'userAgent',
#  'role',
#  'hair.color',
#  'hair.type',
#  'address.address',
#  'address.city',
#  'address.state',
#  'address.stateCode',
#  'address.postalCode',
#  'address.coordinates.lat',
#  'address.coordinates.lng',
#  'address.country',
#  'bank.cardExpire',
#  'bank.cardNumber',
#  'bank.cardType',
#  'bank.currency',
#  'bank.iban',
#  'company.department',
#  'company.name',
#  'company.title',
#  'company.address.address',
#  'company.address.city',
#  'company.address.state',
#  'company.address.stateCode',
#  'company.address.postalCode',
#  'company.address.coordinates.lat',
#  'company.address.coordinates.lng',
#  'company.address.country',
#  'crypto.coin',
#  'crypto.wallet',
#  'crypto.network']

# %%
df.dtypes
# Out:
# id                                   int64
# firstName                              str
# lastName                               str
# maidenName                             str
# age                                  int64
# gender                                 str
# email                                  str
# phone                                  str
# username                               str
# password                               str
# birthDate                              str
# image                                  str
# bloodGroup                             str
# height                             float64
# weight                             float64
# eyeColor                               str
# ip                                     str
# macAddress                             str
# university                             str
# ein                                    str
# ssn                                    str
# userAgent                              str
# role                                   str
# hair.color                             str
# hair.type                              str
# address.address                        str
# address.city                           str
# address.state                          str
# address.stateCode                      str
# address.postalCode                     str
# address.coordinates.lat            float64
# address.coordinates.lng            float64
# address.country                        str
# bank.cardExpire                        str
# bank.cardNumber                        str
# bank.cardType                          str
# bank.currency                          str
# bank.iban                              str
# company.department                     str
# company.name                           str
# company.title                          str
# company.address.address                str
# company.address.city                   str
# company.address.state                  str
# company.address.stateCode              str
# company.address.postalCode             str
# company.address.coordinates.lat    float64
# company.address.coordinates.lng    float64
# company.address.country                str
# crypto.coin                            str
# crypto.wallet                          str
# crypto.network                         str
# dtype: object

# %%
df.isnull().sum().sort_values(ascending=True)
# Out:
# id                                 0
# firstName                          0
# lastName                           0
# maidenName                         0
# age                                0
# gender                             0
# email                              0
# phone                              0
# username                           0
# password                           0
# birthDate                          0
# image                              0
# bloodGroup                         0
# height                             0
# weight                             0
# eyeColor                           0
# ip                                 0
# macAddress                         0
# university                         0
# ein                                0
# ssn                                0
# userAgent                          0
# role                               0
# hair.color                         0
# hair.type                          0
# address.address                    0
# address.city                       0
# address.state                      0
# address.stateCode                  0
# address.postalCode                 0
# address.coordinates.lat            0
# address.coordinates.lng            0
# address.country                    0
# bank.cardExpire                    0
# bank.cardNumber                    0
# bank.cardType                      0
# bank.currency                      0
# bank.iban                          0
# company.department                 0
# company.name                       0
# company.title                      0
# company.address.address            0
# company.address.city               0
# company.address.state              0
# company.address.stateCode          0
# company.address.postalCode         0
# company.address.coordinates.lat    0
# company.address.coordinates.lng    0
# company.address.country            0
# crypto.coin                        0
# crypto.wallet                      0
# crypto.network                     0
# dtype: int64

# %%
x=df.duplicated().sum()
print(x)
# Out:
# 0

# %%
df.describe()
# Out:
#                id         age      height    weight  address.coordinates.lat  \
# count  100.000000  100.000000  100.000000  100.0000               100.000000
# mean    50.500000   31.700000  176.392500   75.0431                 0.304661
# std     29.011492    4.132893   13.838342   14.0146                52.833371
# min      1.000000   23.000000  150.250000   50.1000               -87.184494
# 25%     25.750000   28.750000  166.700000   63.0075               -46.076624
# 50%     50.500000   31.000000  178.320000   75.4600                 3.090987
# 75%     75.250000   34.000000  187.617500   87.5175                42.178338
# max    100.000000   46.000000  199.620000   98.7700                89.781211
#
#        address.coordinates.lng  company.address.coordinates.lat  \
# count               100.000000                       100.000000
# mean                 -8.426883                         3.300877
# std                 105.246649                        51.892119
# min                -176.861979                       -86.557025
# 25%                 -87.475943                       -47.014297
# 50%                 -27.686222                        11.113367
# 75%                  81.048713                        45.542705
# max                 179.922909                        89.270633
#
#        company.address.coordinates.lng
# count                       100.000000
# mean                        -10.039483
# std                         102.017108
# min                        -169.602231
# 25%                         -91.900357
# 50%                         -12.890487
# 75%                          83.312120
# max                         178.506028

# %%
df["gender"].value_counts()
# Out:
# gender
# female    52
# male      48
# Name: count, dtype: int64

# %%
df["bloodGroup"].value_counts()
# Out:
# bloodGroup
# O-     19
# A+     15
# AB+    13
# AB-    13
# B+     12
# B-     10
# O+     10
# A-      8
# Name: count, dtype: int64

# %%
df["eyeColor"].value_counts()
# Out:
# eyeColor
# Brown     18
# Hazel     16
# Gray      14
# Red       12
# Blue      12
# Green     11
# Amber     10
# Violet     7
# Name: count, dtype: int64

# %%
df["role"].value_counts()
# Out:
# role
# user         85
# moderator    10
# admin         5
# Name: count, dtype: int64

# %%
df["address.country"].value_counts()
# Out:
# address.country
# United States    100
# Name: count, dtype: int64

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)

# %%
df["maidenName"].value_counts()

# %%
df.drop("maidenName", axis=1, inplace=True)

# %%
df.tail(5)
# Out:
#      id firstName lastName  age  gender                          email  \
# 95   96    Aurora   Lawson   27  female  aurora.lawson@x.dummyjson.com
# 96   97     Oscar   Powers   34    male   oscar.powers@x.dummyjson.com
# 97   98     Clara    Berry   31  female    clara.berry@x.dummyjson.com
# 98   99     Gavin  Stanley   33    male  gavin.stanley@x.dummyjson.com
# 99  100      Lila   Hudson   28  female    lila.hudson@x.dummyjson.com
#
#                phone username     password  birthDate  \
# 95  +92 802-452-4192  auroral  auroralpass  1998-6-16
# 96  +61 929-572-1408   oscarp   oscarppass   1991-9-7
# 97   +1 390-831-5172   clarab   clarabpass  1994-2-13
# 98  +44 466-358-6026   gavins   gavinspass  1992-3-17
# 99  +91 697-236-1544    lilah    lilahpass   1997-9-1
#
#                                      image bloodGroup  height  weight  \
# 95  https://dummyjson.com/icon/auroral/128         O+  174.28   88.18
# 96   https://dummyjson.com/icon/oscarp/128         O+  169.03   62.55
# 97   https://dummyjson.com/icon/clarab/128         O-  151.55   90.27
# 98   https://dummyjson.com/icon/gavins/128         O-  173.37   92.17
# 99    https://dummyjson.com/icon/lilah/128        AB+  190.10   70.03
#
#    eyeColor               ip         macAddress  \
# 95   Violet   161.244.58.227  34:95:bd:59:f4:39
# 96   Violet  216.204.186.222  79:d9:1b:19:e2:73
# 97      Red   144.153.81.107  30:fa:b2:ca:17:91
# 98    Amber    189.110.169.3    34:32:b0:9:28:0
# 99     Gray     96.35.42.117   96:21:23:2c:f:d5
#
#                           university      ein          ssn  \
# 95                 Boston University  477-337  191-532-292
# 96            University of Virginia  325-379  856-795-126
# 97                    Boston College  246-495  625-638-955
# 98  University of California--Irvine  780-590  321-561-524
# 99          University of Notre Dame  306-959  297-645-204
#
#                                             userAgent  role hair.color  \
# 95  Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:9...  user      Green
# 96  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...  user      Green
# 97  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...  user       Blue
# 98  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...  user      Black
# 99  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...  user     Blonde
#
#    hair.type        address.address address.city address.state  \
# 95      Wavy      1140 Adams Street       Dallas     Minnesota
# 96      Wavy  1948 Jefferson Street    Charlotte       Vermont
# 97      Wavy  1577 Jefferson Street      Seattle       Montana
# 98  Straight     1898 Second Street      Houston   Mississippi
# 99      Wavy       262 Ninth Street      Chicago        Nevada
#
#    address.stateCode address.postalCode  address.coordinates.lat  \
# 95                MN              29004                83.417744
# 96                VT              12263                52.294653
# 97                MT              41818                88.607515
# 98                MS              85234                70.915423
# 99                NV              17472               -68.233207
#
#     address.coordinates.lng address.country bank.cardExpire   bank.cardNumber  \
# 95                -7.933044   United States           07/29  5480171454066942
# 96               -70.699360   United States           11/27  6011597179762975
# 97                92.692781   United States           10/29   348500223799446
# 98               -30.195987   United States           03/27  3581201445671725
# 99               -67.042550   United States           12/29  3573611722474066
#
#        bank.cardType bank.currency               bank.iban  \
# 95        Mastercard           GBP  GB36C9TE2MIXX12X8IJMLG
# 96          Discover           USD  DE16654874987771550206
# 97  American Express           JPY  DE94679076797491453575
# 98               JCB           CAD  DE01439050186894663094
# 99               JCB           EUR  DE23981874800457879322
#
#     company.department                    company.name  \
# 95  Product Management              Hudson - Marquardt
# 96               Legal               Luettgen and Sons
# 97            Training                 Mayer - Smitham
# 98           Marketing  Strosin, Anderson and Baumbach
# 99               Legal     Hartmann, Hilpert and Kulas
#
#                 company.title company.address.address company.address.city  \
# 95  Chief Information Officer        164 Fifth Street         Indianapolis
# 96         Support Specialist         1127 Oak Street              Chicago
# 97                 Accountant        767 Adams Street              Phoenix
# 98         Support Specialist        903 First Street            San Diego
# 99              Sales Manager         1825 Oak Street             New York
#
#    company.address.state company.address.stateCode company.address.postalCode  \
# 95              New York                        NY                      27958
# 96               Alabama                        AL                      37894
# 97            Washington                        WA                      13037
# 98                  Iowa                        IA                      87476
# 99                Kansas                        KS                      71983
#
#     company.address.coordinates.lat  company.address.coordinates.lng  \
# 95                        89.270633                       -72.618747
# 96                        28.080301                        -6.017825
# 97                        76.372465                        24.919329
# 98                       -47.007951                        86.840506
# 99                        50.551530                        39.433391
#
#    company.address.country crypto.coin  \
# 95           United States     Bitcoin
# 96           United States     Bitcoin
# 97           United States     Bitcoin
# 98           United States     Bitcoin
# 99           United States     Bitcoin
#
#                                  crypto.wallet    crypto.network
# 95  0xb9fc2fe63b2a6c003f1c324c3bfa53259162181a  Ethereum (ERC20)
# 96  0xb9fc2fe63b2a6c003f1c324c3bfa53259162181a  Ethereum (ERC20)
# 97  0xb9fc2fe63b2a6c003f1c324c3bfa53259162181a  Ethereum (ERC20)
# 98  0xb9fc2fe63b2a6c003f1c324c3bfa53259162181a  Ethereum (ERC20)
# 99  0xb9fc2fe63b2a6c003f1c324c3bfa53259162181a  Ethereum (ERC20)

# %%
df.drop(["company.address.stateCode","crypto.wallet","company.address.postalCode","bank.iban","macAddress","userAgent","address.postalCode","address.stateCode"], axis=1, inplace=True)

# %%
df.sample(10)
# Out:
#     id  firstName  lastName  age  gender                             email  \
# 53  54        Ava  Harrison   29  female      ava.harrison@x.dummyjson.com
# 23  24      Mateo    Nguyen   31    male      mateo.nguyen@x.dummyjson.com
# 13  14  Charlotte     Lopez   37  female   charlotte.lopez@x.dummyjson.com
# 59  60    Lillian   Simmons   33  female   lillian.simmons@x.dummyjson.com
# 97  98      Clara     Berry   31  female       clara.berry@x.dummyjson.com
# 75  76   Madeline   Simpson   27  female  madeline.simpson@x.dummyjson.com
# 25  26     Evelyn  Gonzalez   36  female   evelyn.gonzalez@x.dummyjson.com
# 90  91       Levi     Hicks   30    male        levi.hicks@x.dummyjson.com
# 2    3     Sophia     Brown   43  female      sophia.brown@x.dummyjson.com
# 95  96     Aurora    Lawson   27  female     aurora.lawson@x.dummyjson.com
#
#                phone    username        password  birthDate  \
# 53  +44 926-778-4653        avah        avahpass  1996-4-22
# 23   +1 341-597-6694      mateon      mateonpass   1994-6-2
# 13  +44 373-953-5028  charlottem  charlottempass   1988-6-8
# 59  +61 857-625-2029    lillians    lillianspass   1992-3-9
# 97   +1 390-831-5172      clarab      clarabpass  1994-2-13
# 75  +44 371-964-4017   madelines   madelinespass  1998-12-1
# 25  +61 708-508-4638     evelyng     evelyngpass   1989-2-5
# 90  +92 931-753-3850       levih       levihpass  1995-5-19
# 2   +81 210-652-2785     sophiab     sophiabpass  1982-11-6
# 95  +92 802-452-4192     auroral     auroralpass  1998-6-16
#
#                                         image bloodGroup  height  weight  \
# 53        https://dummyjson.com/icon/avah/128         O-  155.72   93.47
# 23      https://dummyjson.com/icon/mateon/128         O+  174.29   59.98
# 13  https://dummyjson.com/icon/charlottem/128        AB-  178.92   82.46
# 59    https://dummyjson.com/icon/lillians/128         A+  173.72   87.33
# 97      https://dummyjson.com/icon/clarab/128         O-  151.55   90.27
# 75   https://dummyjson.com/icon/madelines/128        AB+  181.51   67.70
# 25     https://dummyjson.com/icon/evelyng/128         O+  168.94   58.47
# 90       https://dummyjson.com/icon/levih/128         A-  199.06   95.68
# 2      https://dummyjson.com/icon/sophiab/128         O-  177.72   52.60
# 95     https://dummyjson.com/icon/auroral/128         O+  174.28   88.18
#
#    eyeColor              ip                          university      ein  \
# 53    Hazel  225.40.138.177                  Harvard University  145-780
# 23      Red    192.57.144.7                 Columbia University  229-249
# 13    Brown   119.103.95.60             Northeastern University  364-782
# 59     Gray  161.193.124.63                   Boston University  504-909
# 97      Red  144.153.81.107                      Boston College  246-495
# 75    Brown   29.230.204.12             University of Rochester  795-274
# 25      Red    42.52.74.232  Washington University in St. Louis  569-275
# 90      Red  235.155.45.205               Ohio State University  858-254
# 2     Hazel  214.225.51.195               Pepperdine University  963-113
# 95   Violet  161.244.58.227                   Boston University  477-337
#
#             ssn       role hair.color hair.type        address.address  \
# 53  621-536-422       user      Brown     Curly      1094 Adams Street
# 23  416-877-230       user     Purple      Wavy     1578 Fourth Street
# 13  255-491-479  moderator       Gray     Kinky      208 Second Street
# 59  593-729-652       user      Black     Kinky    1577 Seventh Street
# 97  625-638-955       user       Blue      Wavy  1577 Jefferson Street
# 75  220-119-957       user     Blonde  Straight        1466 Oak Street
# 25  487-680-127       user      Black      Wavy    1065 Lincoln Street
# 90  510-891-185       user       Blue     Curly       1836 Pine Street
# 2   638-461-822      admin      White      Wavy      1642 Ninth Street
# 95  191-532-292       user      Green      Wavy      1140 Adams Street
#
#    address.city  address.state  address.coordinates.lat  \
# 53  San Antonio        Vermont               -84.032892
# 23     Columbus       Missouri               -32.828675
# 13     Columbus           Ohio               -44.443762
# 59      Phoenix      Minnesota               -78.054184
# 97      Seattle        Montana                88.607515
# 75  Los Angeles     New Jersey               -61.252684
# 25       Dallas          Maine                67.768359
# 90      Phoenix  West Virginia                43.752994
# 2    Washington        Alabama                45.289366
# 95       Dallas      Minnesota                83.417744
#
#     address.coordinates.lng address.country bank.cardExpire   bank.cardNumber  \
# 53               -46.255902   United States           01/27  3694482369735209
# 23               -82.557354   United States           12/29  4021840414995098
# 13              -151.420561   United States           12/27  3634388457177035
# 59              -159.412033   United States           08/28  4194199742529819
# 97                92.692781   United States           10/29   348500223799446
# 75              -159.370289   United States           10/28  5598889672042796
# 25                71.268643   United States           08/28  6011735364912274
# 90               -60.845798   United States           08/27  6011037232328647
# 2                 46.832664   United States           10/27  6011212053392887
# 95                -7.933044   United States           07/29  5480171454066942
#
#                 bank.cardType bank.currency        company.department  \
# 53  Diners Club International           AUD               Engineering
# 23                       Visa           CAD                Accounting
# 13  Diners Club International           PKR                Accounting
# 59                       Visa           AUD      Business Development
# 97           American Express           JPY                  Training
# 75                 Mastercard           EUR        Product Management
# 25                   Discover           CAD                Accounting
# 90                   Discover           CAD        Product Management
# 2                    Discover           EUR  Research and Development
# 95                 Mastercard           GBP        Product Management
#
#                 company.name              company.title  \
# 53         Blanda - Jacobson              Legal Counsel
# 23                Spinka LLC           Business Analyst
# 13           Zulauf and Sons    Chief Executive Officer
# 59     Will, Stamm and Zieme              Legal Counsel
# 97           Mayer - Smitham                 Accountant
# 75             King - Muller              Web Developer
# 25  Tromp, Gaylord and Weber            Project Manager
# 90               Quitzon LLC         Software Architect
# 2           Schiller - Zieme                 Accountant
# 95        Hudson - Marquardt  Chief Information Officer
#
#    company.address.address company.address.city company.address.state  \
# 53       1374 Cedar Street         Philadelphia              Delaware
# 23   1967 Jefferson Street               Dallas             Louisiana
# 13    569 Jefferson Street          Los Angeles               Montana
# 59       1624 Maple Street               Denver               Montana
# 97        767 Adams Street              Phoenix            Washington
# 75       1090 Fifth Street         Jacksonville                  Utah
# 25        584 Ninth Street         Jacksonville             Wisconsin
# 90          388 Elm Street            Charlotte               Vermont
# 2   1896 Washington Street               Dallas                Nevada
# 95        164 Fifth Street         Indianapolis              New York
#
#     company.address.coordinates.lat  company.address.coordinates.lng  \
# 53                       -56.564069                      -134.428790
# 23                        75.982676                       164.459743
# 13                       -18.371256                        22.566258
# 59                       -17.662779                       165.102747
# 97                        76.372465                        24.919329
# 75                        12.345847                        90.721037
# 25                        26.014021                        40.572436
# 90                        18.856177                        36.280746
# 2                         20.086743                       -34.577107
# 95                        89.270633                       -72.618747
#
#    company.address.country crypto.coin    crypto.network
# 53           United States     Bitcoin  Ethereum (ERC20)
# 23           United States     Bitcoin  Ethereum (ERC20)
# 13           United States     Bitcoin  Ethereum (ERC20)
# 59           United States     Bitcoin  Ethereum (ERC20)
# 97           United States     Bitcoin  Ethereum (ERC20)
# 75           United States     Bitcoin  Ethereum (ERC20)
# 25           United States     Bitcoin  Ethereum (ERC20)
# 90           United States     Bitcoin  Ethereum (ERC20)
# 2            United States     Bitcoin  Ethereum (ERC20)
# 95           United States     Bitcoin  Ethereum (ERC20)

# %%
df[["age", "height", "weight"]].isnull().sum()
# Out:
# age       0
# height    0
# weight    0
# dtype: int64

# %%
df["age"].fillna(df["age"].median(), inplace=True)
df["height"].fillna(df["height"].median(), inplace=True)
df["weight"].fillna(df["weight"].median(), inplace=True)
# Out:
# C:\Users\eLROWAD\AppData\Local\Temp\ipykernel_2120\187645330.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df["age"].fillna(df["age"].median(), inplace=True)
# C:\Users\eLROWAD\AppData\Local\Temp\ipykernel_2120\187645330.py:2: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df["height"].fillna(df["height"].median(), inplace=True)
# C:\Users\eLROWAD\AppData\Local\Temp\ipykernel_2120\187645330.py:3: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df["weight"].fillna(df["weight"].median(), inplace=True)
# 0     63.16
# 1     76.32
# 2     52.60
# 3     62.10
# 4     63.62
#       ...
# 95    88.18
# 96    62.55
# 97    90.27
# 98    92.17
# 99    70.03
# Name: weight, Length: 100, dtype: float64

# %%
# !pip install matplotlib seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 import matplotlib.pyplot as plt
#       2 import seaborn as sns
#       4 sns.set(style="whitegrid")
#
# ModuleNotFoundError: No module named 'matplotlib'
